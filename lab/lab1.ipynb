# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
lab1=pd.read_csv("/Users/mohao/Downloads/ммо/лаб1/lab11.csv")

# %%
lab1.head()
# Out:
#                                      university  year rank_display  score  \
# 0  Massachusetts Institute of Technology (MIT)   2017            1  100.0
# 1                           Stanford University  2017            2   98.7
# 2                            Harvard University  2017            3   98.3
# 3                       University of Cambridge  2017            4   97.2
# 4  California Institute of Technology (Caltech)  2017            5   96.9
#
#                                                 link         country  \
# 0  https://www.topuniversities.com/universities/m...   United States
# 1  https://www.topuniversities.com/universities/s...   United States
# 2  https://www.topuniversities.com/universities/h...   United States
# 3  https://www.topuniversities.com/universities/u...  United Kingdom
# 4  https://www.topuniversities.com/universities/c...   United States
#
#         city         region  \
# 0  Cambridge  North America
# 1   Stanford  North America
# ...

# %%
lab1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6482 entries, 0 to 6481
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   university              6482 non-null   object
#  1   year                    6482 non-null   int64
#  2   rank_display            6414 non-null   object
#  3   score                   2820 non-null   float64
#  4   link                    6482 non-null   object
#  5   country                 6482 non-null   object
#  6   city                    6304 non-null   object
#  7   region                  6482 non-null   object
#  8   logo                    6482 non-null   object
#  9   type                    6470 non-null   object
#  10  research_output         6480 non-null   object
#  11  student_faculty_ratio   6407 non-null   float64
#  12  international_students  6318 non-null   object
#  13  size                    6480 non-null   object
# ...

# %%
lab1.drop(["link","logo"],axis=1)
# Out:
#                                         university  year rank_display  score  \
# 0     Massachusetts Institute of Technology (MIT)   2017            1  100.0
# 1                              Stanford University  2017            2   98.7
# 2                               Harvard University  2017            3   98.3
# 3                          University of Cambridge  2017            4   97.2
# 4     California Institute of Technology (Caltech)  2017            5   96.9
# ...                                            ...   ...          ...    ...
# 6477                           Université de Tunis  2022         1201    NaN
# 6478                  Université de Tunis El Manar  2022         1201    NaN
# 6479                            Yarmouk University  2022         1201    NaN
# 6480                   Yildiz Technical University  2022         1201    NaN
# 6481                            Zagazig University  2022         1201    NaN
#
# ...

# %%
lab1.isnull().sum()
# Out:
# university                   0
# year                         0
# rank_display                68
# score                     3662
# link                         0
# country                      0
# city                       178
# region                       0
# logo                         0
# type                        12
# research_output              2
# student_faculty_ratio       75
# international_students     164
# size                         2
# faculty_count               78
# dtype: int64

# %%
lab1.isnull().melt()
# Out:
#             variable  value
# 0         university  False
# 1         university  False
# 2         university  False
# 3         university  False
# 4         university  False
# ...              ...    ...
# 97225  faculty_count  False
# 97226  faculty_count  False
# 97227  faculty_count  False
# 97228  faculty_count  False
# 97229  faculty_count  False
#
# [97230 rows x 2 columns]

# %%
sns.displot(data=lab1.isnull().melt(),y='variable',hue='value',multiple='fill',aspect=2)
plt.title('missing values')
# Out:
# Text(0.5, 1.0, 'missing values')

# %%
lab1.loc[:,"score"].fillna(value=0)
# Out:
# 0       100.0
# 1        98.7
# 2        98.3
# 3        97.2
# 4        96.9
#         ...
# 6477      0.0
# 6478      0.0
# 6479      0.0
# 6480      0.0
# 6481      0.0
# Name: score, Length: 6482, dtype: float64

# %%
lab1.loc[:,'city'].fillna(value='unkonw',inplace=True)

# %%
lab1.loc[:,'rank_display'].fillna(value='out of range',inplace=True)

# %%
lab1.isnull().sum()
# Out:
# university                   0
# year                         0
# rank_display                 0
# score                     3662
# link                         0
# country                      0
# city                         0
# region                       0
# logo                         0
# type                        12
# research_output              2
# student_faculty_ratio       75
# international_students     164
# size                         2
# faculty_count               78
# dtype: int64

# %%
sns.displot(lab1['score'])

# %%
lab1.loc[:,'faculty_count']=lab1.loc[:,'faculty_count'].str.replace(',', '').astype(float)
lab1.loc[:,'student_faculty_ratio'].astype(float)
lab1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6482 entries, 0 to 6481
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   university              6482 non-null   object
#  1   year                    6482 non-null   int64
#  2   rank_display            6482 non-null   object
#  3   score                   2820 non-null   float64
#  4   link                    6482 non-null   object
#  5   country                 6482 non-null   object
#  6   city                    6482 non-null   object
#  7   region                  6482 non-null   object
#  8   logo                    6482 non-null   object
#  9   type                    6470 non-null   object
#  10  research_output         6480 non-null   object
#  11  student_faculty_ratio   6407 non-null   float64
#  12  international_students  6318 non-null   object
#  13  size                    6480 non-null   object
# ...

# %%
sns.jointplot(x='student_faculty_ratio',y='faculty_count',data=lab1,kind="hex")
sns.catplot(x="year", y="score", kind="box", data=lab1)

# %%
sns.pairplot(lab1,plot_kws=dict(linewidth=0))

# %%
import re

# %%
lab1['international_students'] = lab1.international_students.str.replace(r'\W+','').astype(float)
# Out:
# /var/folders/9l/v94s42394sv1b6r8jrdc1w980000gn/T/ipykernel_11161/472355414.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   lab1['international_students'] = lab1.international_students.str.replace(r'\W+','').astype(float)

# %%
lab1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6482 entries, 0 to 6481
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   university              6482 non-null   object
#  1   year                    6482 non-null   int64
#  2   rank_display            6482 non-null   object
#  3   score                   2820 non-null   float64
#  4   link                    6482 non-null   object
#  5   country                 6482 non-null   object
#  6   city                    6482 non-null   object
#  7   region                  6482 non-null   object
#  8   logo                    6482 non-null   object
#  9   type                    6470 non-null   object
#  10  research_output         6480 non-null   object
#  11  student_faculty_ratio   6407 non-null   float64
#  12  international_students  6318 non-null   float64
#  13  size                    6480 non-null   object
# ...

# %%
sns.heatmap(lab1.corr(),annot=True)
plt.title('Correlation Matrix')
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %%
sns.set_style('white')
sns.lmplot(data=lab1,x='international_students',y='faculty_count',
          aspect=2,height=8)
plt.title('Plot of the linear regression between number of faculty and number of  international students', fontsize=20,
          color="green")
plt.xlabel('Number of International Students')
plt.ylabel('Number of Faculty')
# Out:
# Text(5.924999999999997, 0.5, 'Number of Faculty')

# %%
sns.set_style('dark')
plt.figure(figsize=(10,12))
sns.barplot(
    data=lab1,x="year", y='international_students', hue='type',palette='viridis')
plt.legend(bbox_to_anchor=(1, 1), loc='upper right')
plt.title('Number of international students in private and public universities from 2017-2022', fontsize=20,
          color="purple")
plt.ylabel('Number of International Students')
plt.xlabel('Type of University')
# Out:
# Text(0.5, 0, 'Type of University')

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import plotly.express as px

# %%
graph=lab1[['international_students','country']].groupby('country').sum().sort_values(by='international_students',ascending=False)

# %%
sns.set_style('dark')
plt.figure(figsize=(10,12))
sns.barplot(
    data=graph, x='international_students', y=graph.index, palette='viridis')
plt.title('Top 100 Countries of Choice for International Students for the Years 2017-2022', fontsize=15,
          color="purple")
plt.ylabel('Countries', fontsize=20)
plt.xlabel('count', fontsize=20)
# Out:
# Text(0.5, 0, 'count')
